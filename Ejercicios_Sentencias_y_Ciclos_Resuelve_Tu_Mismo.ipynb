# %% [markdown]
# # 📝 Ejercicios de Sentencias Condicionales y Ciclos en Python
# Ejercicios para que completes por ti mismo. ¡Practica lo aprendido!

# %% [markdown]
# ## 🔹 Ejercicio 1: ¿Mayor de edad?
# Escribe un programa que pregunte la edad de una persona y diga si es **mayor de edad** (18 años o más) o **menor de edad**.

# %%
# Tu código aquí

# %% [markdown]
# ## 🔹 Ejercicio 2: Imprimir números del 1 al 10
# Utiliza un bucle `for` para imprimir los números del 1 al 10.

# %%
# Tu código aquí

# %% [markdown]
# ## 🔹 Ejercicio 3: Suma de números pares
# Suma todos los números pares del 0 al 50 utilizando un bucle.

# %%
# Tu código aquí

# %% [markdown]
# ## 🔹 Ejercicio 4: Cuenta regresiva
# Imprime una cuenta regresiva desde 5 hasta 1 utilizando `while`.

# %%
# Tu código aquí

# %% [markdown]
# ## 🔹 Ejercicio 5: Saltar el número 3
# Imprime los números del 1 al 5, pero **omite** el número 3 utilizando `continue`.

# %%
# Tu código aquí
